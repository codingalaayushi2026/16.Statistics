# %% [markdown]
# <a href="https://colab.research.google.com/github/codingalaayushi2026/16.Statistics/blob/main/Lesson4_Activity2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

"""####**Import Dataset**

from google.colab import files
uploaded = files.upload()"""

# Import dataset
data = pd.read_csv('Titanic Dataset.csv')

data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 4            373450   8.0500   NaN        S    male

# %%
"""#### **Set Plot Style**"""

sns.set_style('whitegrid')

# %%
"""#### **Countplot for feature 'Survived'**"""

sns.countplot(x='Survived', data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
"""#### **Barchart for showing passengers belonging to different gender who survived or not**

"""

sns.countplot(x='Gender', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
"""#### **Customize Plots**"""

sns.countplot(x='Survived', data=data, palette='winter')

sns.countplot(x='Gender', hue='Survived', data=data, palette='winter')
# Out:
# /tmp/ipykernel_3029/2557810561.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='winter')
# <Axes: xlabel='Survived', ylabel='count'>

# %%
"""#### **Customize Plots**"""

sns.countplot(x='Survived', data=data, palette='winter')

sns.countplot(x='Gender', hue='Survived', data=data, palette='winter')
# Out:
# /tmp/ipykernel_3029/2557810561.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='winter')
# <Axes: xlabel='Survived', ylabel='count'>
